# %% [markdown]
# Выполнил: __Орлов Михаил Федорович, Р3121__

# %% [markdown]
# # Предсказание цен на недвижимость
#
# **Бизнес-постановка задачи**
#
# Компании по продаже недвижимости оценивают ее стоимость, используя методы машинного обучения.
# Задача оценки цены на недвижимость также может быть нужна для:
# * выявления аномально низких цен на недвижимость,
# * оценки макроэкономических показателей,
# * уточнения ставок по ипотеке

# %% [markdown]
# **Постановка задачи анализа данных**
#
# Целью данной задачи является прогнозирование стоимости домов в округе Кинг (штат Вашингтон, США) с помощью построения регрессионных моделей и их анализа. Набор данных состоит из цен на дома в округе Кинг, проданных в период с мая 2014 года по май 2015 года. Данные опубликованы в открытом доступе на платформе Kaggle.

# %% [markdown]
# Данные с сайта renthub.com по стоимости квартир для аренды в Сиэтле:

# %% [markdown]
# <a href="https://drive.google.com/uc?id=1Dr-p-o5yMi3uIS2kPcUUwT5bH0cCt1Be
# " target="_blank"><img src="https://drive.google.com/uc?id=1Dr-p-o5yMi3uIS2kPcUUwT5bH0cCt1Be"
# alt="IMAGE ALT TEXT HERE" width="360" border="0" /></a>

# %% [markdown]
# **Обзор доступных данных**
#
# В выборке 21613 наблюдений и 21 переменная.
# Таким образом, про каждый из 21613 объектов недвижимости мы знаем значения 21 их характеристики (число спален, оценка состояния риелтором, наличие вида на воду и т.п.)
#
# Выборка была разбита на две части для обучения и для тестирования модели. Данные на обучение и тест обычно делят случайно и равномерно: нужно чтобы и обучающая, и тестовая выборка были похожие на те данные, на которых модель будет использоваться в боевых условиях.
#
# Более сложные разбиения могут использоваться если в данных есть временная компонента - например, мы строим скоринговую модель и для теста откладываем данные за последние несколько месяцев, а всю остальную выборку используем для обучения. Такое разбиение имитирует реальную работу модели: мы можем обучаться только на данных прошлых кредитов, а работать модель уже будет на данных из будущего.
#
# Доли общей выборки для обучения и тестирования обычно 70% и 30% соотвественно. Любые разумные числа подходят, если для обучения используется достаточно много данных (обычно больше 50%), но и для тестирования что-то остается (10% и больше).

# %% [markdown]
# Данные содержат два типа переменных:
#
# * Целевая: **Целевая. Цена**
# * Остальные переменные: **20 переменных, могут использоваться для прогноза целевой переменной.**

# %% [markdown]
# ## План анализа данных (data mining):
#
#   1. Загрузить данные для обучения
#   2. Обработать данные перед обучением модели
#   3. Обучить модель на обучающей выборке
#   4. Загрузить и предобработать данные для тестирования
#   5. Провалидировать модель на тестовой выборке

# %% [markdown]
# ## 1. Загрузить данные для обучения

# %% [markdown]
# **Шаг 1.1. Загружаем библиотеки**

# %% [markdown]
# Библиотека **warnings** отвечает за то, какие предупреждения (warnings) о работе будут выводиться пользователю.
# FutureWarning - предупреждения о том, как изменится работа библиотек в будущих версиях.
# Поэтому такие предупреждения мы будем игнорировать.
# Чтобы включить режим игнорирования мы отбираем все предупреждения из категории FutureWarning и выбираем для них действия 'ignore'.
# Это делается вызовом функции simplefilter c задание двух атрибутов: действия action и категории предупреждений category.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Для корректной работы с данными в python требуется загрузить специальную библиотеку
# **pandas**, программную библиотеку на языке python для обработки и анализа данных.

# %%
import pandas as pd # загружаем библиотеку и для простоты обращения в коде называем её сокращенно pd

# %% [markdown]
# Для корректной работы с графиками в python требуется загрузить специальную библиотеку
# **matplotlib**, программную библиотеку на языке python для визуализации данных двумерной и трехмерной графикой.
#
# Графики используются для облегчения интерпретации полученных результатов, а также в качестве иллюстраций в презентациях и отчетах.
#
# Основные методы для построения:
# * plot() - графики
# * semilogy() - график логарифметический
# * hist() - гистограммы

# %%
import matplotlib.pyplot as plt # загружаем библиотеку и для простоты обращения в коде называем её сокращенно plt
# указываем, чтобы картинки отображались прямо в ноутбуке
# %matplotlib inline

# %% [markdown]
# **Шаг 1.2. Загрузим данные**

# %% [markdown]
# Для решения задачи мы будем использовать данные. Они состоят из двух частей: часть для обучения и часть для тестирования модели. Загружаем данные с помощие команды !wget. Для того, чтобы игнорировать сообщения в процессе загрузки используем магическую команду %%capture в первой строке.

# %%
# %%capture
# !wget https://www.dropbox.com/s/afwb0tnqm9izxha/predict_house_price_training_data.xlsx
# !wget https://www.dropbox.com/s/sur2avqf4n5f4az/predict_house_price_test_data.xlsx

# %% [markdown]
# Так как данные в формате xlsx (Excel), мы будем использовать специальную функцию
# из библиотеки pandas для загрузки таких данных **read_excel**.
#
# В функции передаем один атрибут: название таблицы с данными.

# %%
training_data = pd.read_excel('predict_house_price_training_data.xlsx') # загружаем таблицу в переменную training_data

# %%
type(training_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# training_data.tail(2)

training_data.sample(10)
# Out:
#        Целевая.Цена  Спальни  Ванные  Жилая площадь  Общая площадь  \
# 7920         250000        3    1.75           1160           6134
# 12611        575000        4    2.50           3020          17810
# 4506         276900        3    1.00           1270           7566
# 9376         826000        3    3.25           2330           4000
# 13041        580000        3    2.25           1670           7416
# 7783         402000        3    1.50           1450           7375
# 7150         415000        3    2.50           1610           3600
# 10047       1110000        6    4.00           3600           6224
# 6836         866800        4    3.50           2970           5000
# 427          185000        3    1.50           1010           7755
#
#        Количество этажей  Вид на воду  Просмотрены ранее  Состояние  \
# 7920                 1.0            0                  0          3
# 12611                1.0            0                  0          3
# ...

# %% [markdown]
# *Что важно посмотреть после того, как мы загрузили данные?*
# - проверить, что данные действительно загрузились
# - посмотреть на данные, чтобы удостовериться, что они правильные: колонки имеют те же названия, что и в таблице и т.д.
#
# Для того чтобы это сделать, нужно вызвать от переменной *training_data* метод **head()**, который выводит первые 5 строк таблицы.
#
# Для вызова метода объекта необходимо сначала написать *имя объекта*, затем поставить *точку*, затем уже написать *название метода*. Обратите внимание, что в конце обязательно ставить скобочки, потому что метод - это функция и в ней есть аргументы, просто в данном случае мы их не передаем, поэтому оставляем поле пустым

# %%
training_data.head()
# Out:
#    Целевая.Цена  Спальни  Ванные  Жилая площадь  Общая площадь  \
# 0        830000        5    3.50           3490          21780
# 1        385000        4    1.75           2360           7620
# 2        610000        6    2.75           2040           8560
# 3        550000        3    1.75           1940           8376
# 4       1300000        3    2.75           3450           5350
#
#    Количество этажей  Вид на воду  Просмотрены ранее  Состояние  \
# 0                2.0            0                  0          3
# 1                1.0            0                  0          4
# 2                1.0            0                  2          4
# 3                1.0            0                  0          4
# 4                1.5            0                  3          4
#
#    Оценка риелтора  Площадь без подвала  Площадь подвала  Год постройки  \
# 0                8                 3490                0           1996
# ...

# %% [markdown]
# **Шаг 1.3. Посмотрим на размеры загруженной таблицы**, у которой мы видели только первые 5 строк.
#
# Для этого вызываем поле **shape** у нашей переменной *training_data*. Поле вызывается также как метод, но в конце скобки не ставятся, так как для поля не предусмотрена передача аргументов.

# %%
training_data.shape
# Out:
# (15129, 16)

# %% [markdown]
# *Что означает первое и второе число?*
#
# Итак, таблица содержит 15129 строк (объектов) и 16 столбцов (признаков), включая выходной (целевой) признак.
# 15129 меньше 21613, так как мы пока загрузили только часть данных, которую будем использовать для обучения модели.
#
# Таблицу проверили, теперь можно приступать к обработке данных.

# %% [markdown]
# # 2. Обработать данные перед обучением модели

# %% [markdown]
# **Шаг 2.1. Проверяем данные на наличие пропусков и типов переменных**
#
# Начнем с проверки общей информации о данных.
# Для того чтобы это сделать, нужно обратиться вызвать у переменной *training_data* метод **info()**.
#
# Напомним, что в конце необходимо поставить скобочки.

# %%
# 1. TO DO
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15129 entries, 0 to 15128
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Целевая.Цена         15129 non-null  int64
#  1   Спальни              15129 non-null  int64
#  2   Ванные               15129 non-null  float64
#  3   Жилая площадь        15129 non-null  int64
#  4   Общая площадь        15129 non-null  int64
#  5   Количество этажей    15129 non-null  float64
#  6   Вид на воду          15129 non-null  int64
#  7   Просмотрены ранее    15129 non-null  int64
#  8   Состояние            15129 non-null  int64
#  9   Оценка риелтора      15129 non-null  int64
#  10  Площадь без подвала  15129 non-null  int64
#  11  Площадь подвала      15129 non-null  int64
#  12  Год постройки        15129 non-null  int64
#  13  Год реновации        15129 non-null  int64
#  14  Широта               15129 non-null  float64
# ...

# %% [markdown]
# Анализируем результата выполнения команды:
#
# * 15129 строк (entries)
# * 16 столбцов (Data columns)
#
# В данных присутствует всего два типа dtypes:
# * int64 - целое число  (12 столбцов)
# * float64 - дробное число (4 столбца)
#
# Цифры в каждой строчке обозначают количество заполненных (*non-null*) значений. Так как эти цифры в каждой строчке совпадают с числом строк (15129), то в данных нет пропусков и можно двигаться дальше.

# %% [markdown]
# **Шаг 2.2. Работаем с целевой переменной**
#
# *Какая переменная целевая?*
#
# В данном случае по условию задачи мы должны прогнозировать стоимость, поэтому целевая переменная - это цена.

# %%
target_variable_name = 'Целевая.Цена'

# %% [markdown]
# Нам нужно выделить в отдельную переменную *training_values* столбец из нашей таблицы, который соответствует определенной выше целевой переменной. Для этого мы у таблицы *training_data* в квадратных скобках указываем имя нужного столбца. В нашем случае это имя записано в переменной *target_variable_name*.

# %%
training_values = training_data[target_variable_name]

training_values.shape
# Out:
# (15129,)

# %% [markdown]
# Отделим входные переменные от выходной (целевой), чтобы можно было построить модель предсказания целевой переменной по входным.
# Для это нужно у переменной *training_data* вызвать метод **drop()**. Результат мы записываем в новую переменную *training_points*. После выполнения запроса *training_points* будет содержать исходную таблицу без целевого столбца.
#
# Обратите внимание, что в данном случае мы передаем два аргумента:
#     1. target_variable_name - название столбца цены, который мы ранее записали в эту переменную и теперь хотим удалить из training_data
#     2. axis=1 - означает, что мы удаляем столбец, а в случае axis=0 - означает, что мы удаляем строку

# %%
#  2. TO DO
training_points = training_data.drop(columns=target_variable_name)

# %%
training_data.shape
# Out:
# (15129, 16)

# %% [markdown]
# Можно посмотреть результаты этих действий, вызвав метод **head()** и поле **shape**, которыми мы пользовались ранее, но сейчас нужно вызывать их от новой переменной *training_points*.

# %%
training_points.head()
# Out:
#    Спальни  Ванные  Жилая площадь  Общая площадь  Количество этажей  \
# 0        5    3.50           3490          21780                2.0
# 1        4    1.75           2360           7620                1.0
# 2        6    2.75           2040           8560                1.0
# 3        3    1.75           1940           8376                1.0
# 4        3    2.75           3450           5350                1.5
#
#    Вид на воду  Просмотрены ранее  Состояние  Оценка риелтора  \
# 0            0                  0          3                8
# 1            0                  0          4                7
# 2            0                  2          4                7
# 3            0                  0          4                8
# 4            0                  3          4                9
#
#    Площадь без подвала  Площадь подвала  Год постройки  Год реновации  \
# 0                 3490                0           1996              0
# ...

# %%
training_points.shape
# Out:
# (15129, 15)

# %% [markdown]
# Видно, что столбца действительно нет, а количество строк не изменилось. Данные в 5 первых строках такие же, как были ранее.

# %% [markdown]
# ##   3. Обучить модель на обучающей выборке

# %% [markdown]
# **Шаг 3.1. Выбираем метод, который будем использовать**
#
# Проще всего начать с простых методов.
# Мы воспользуемся двумя методами для построения моделей и сравним их между собой:
# * Линейная регрессия *linear regression*
# * Лес решающих деревьев *random forest*
#
# На выбор метода для построения модели влияет набор признаков, размер выборки, интуиция про то, какая связь между входными переменными и целевой. Но часто решение принимается исходя из того, какая модель сработала лучше.

# %% [markdown]
# Для корректной работы с методами построения моделей в python требуется загрузить специальную библиотеку
# **sklearn**, программную библиотеку на языке python для для машинного обучения и анализа данных.
#
# Мы импортируем два модуля из этой библиотеки:
#  * *linear_model* - тут находятся все линейные модели
#  * *ensemble* - тут находятся модели на основе ансамблей

# %%
from sklearn import linear_model, ensemble

# %% [markdown]
# Прежде чем начать делать ремонт, нужно подготовить инструменты для работы. Аналогично в нашем случае, прежде чем обучать модели, нужно создать их прототипы.

# %% [markdown]
# Чтобы создать модель линейной регресии, пишем имя модуля 'linear_model', затем точку, затем название модели.
#
# Для этого нужно выполнить следующий код:
#
# ```python
# linear_regression_model = linear_model.LinearRegression()
# linear_regression_model
# ```
#
# Результат выполнения должен быть следующим:
#
# ```python
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# ```

# %%
linear_regression_model = linear_model.LinearRegression() # создаем модель

# %%
# linear_regression_model # смотрим, что получилось

print(linear_regression_model)
# Out:
# LinearRegression()

# %% [markdown]
# Чтобы создать модель случайного леса, пишем имя модуля ensemble, затем точку, затем название модели.
#
# Для этого нужно выполнить следующий код:
#
# ```python
# random_forest_model = ensemble.RandomForestRegressor()
# random_forest_model
# ```
# Результат выполнения должен быть следующим:
#
# ```python
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)
# ```

# %%
# Создайте модель RandomForest

# 3. TO DO: вписать строчку выше и раскомментировать код

random_forest_model = ensemble.RandomForestRegressor()
random_forest_model
# Out:
# RandomForestRegressor()

# %% [markdown]
# У модели на основе случайного леса больше параметров. Рассмотрим наиболее важные:
# * параметр *n_estimators* определяет, сколько деревьев в лесу,
# * в параметре *max_depth* устанавливается, какая максимальная глубина у дерева,
# * в параметре *min_samples_leaf* задается, какое минимальное число объектов может попасть в лист дерева.

# %% [markdown]
# Так как у модели на основе случайного решающего леса больше параметров, такая модель обычно обучается медленнее.
# Кроме этого, на время обучения влияют значения параметров модели. Например, чем больше деревьев в лесе - тем дольше модель будет учиться.

# %% [markdown]
# **Шаг 3.2. Обучить модель**
#
# Теперь, когда мы создали прототипы обеих моделей, можем их обучить с помощью обучающей выборки.
#
# Для этого вызываем метод **fit()** у каждой модели и передаем ему на вход два аргумента:
# таблицу входных признаков и столбец значений целевой переменной - (training_points, training_values)

# %%
# 4. TO DO

linear_regression_model.fit(training_points, training_values)
# Out:
# LinearRegression()

# %% [markdown]
# Делаем тоже самое для модели решающего леса.

# %%
# 5. TO DO

random_forest_model.fit(training_points, training_values)
# Out:
# RandomForestRegressor()

# %% [markdown]
# * Для двух разных моделей в sklearn методы для обучения модели не отличаются.
# * Мы получили две обученные модели.
# * Теперь необходимо провалидировать модели на новых тестовых данных.

# %% [markdown]
# ## 4. Загрузить и предобработать данные для тестирования

# %% [markdown]
# **Шаг 4.1. Загрузим и проанализируем тестовые данные.**
#
# Так как данные в формате xlsx (Excel), мы будем использовать специальную функцию
# из библиотеки pandas для загрузки таких данных **read_excel**.
#
# В функции передаем один атрибут: название файла, в котором находится таблица с данными.

# %%
test_data = pd.read_excel('predict_house_price_test_data.xlsx')

# %% [markdown]
# *Что важно посмотреть, после того, как мы загрузили данные?*
#
# - проверить, что данные действительно загрузились
# - посмотреть на данные, чтобы удостовериться, что они правильные: колонки имеют те же названия, что и в таблице и т.д.
#
# Для того чтобы это сделать, нужно вызвать от переменной *test_data* метод **head()**, который выводит первые 5 строк таблицы.
#
# Для вызова метода объекта необходимо сначала написать *имя объекта*, затем поставить *точку*, затем уже написать *название метода*. Обратите внимание, что в конце обязательно ставить скобочки, потому что метод - это функция и в ней есть аргументы, просто в данном случае мы их не передаем, поэтому оставляем поле пустым

# %%
test_data.head()
# Out:
#    Целевая.Цена  Спальни  Ванные  Жилая площадь  Общая площадь  \
# 0        260000        3    1.00           1300          10139
# 1        734500        4    2.75           3280           6845
# 2        325000        1    1.00           1220          12426
# 3       1990000        3    2.50           2880          13500
# 4        315000        3    2.00           1300           3731
#
#    Количество этажей  Вид на воду  Просмотрены ранее  Состояние  \
# 0                1.0            0                  0          3
# 1                2.0            0                  0          3
# 2                1.0            0                  4          4
# 3                1.0            0                  4          5
# 4                1.0            0                  0          3
#
#    Оценка риелтора  Площадь без подвала  Площадь подвала  Год постройки  \
# 0                7                 1300                0           1962
# ...

# %% [markdown]
# Посмотрим на размеры загруженной таблицы, так как мы видели только 5 строк
#
# Для этого вызываем поле **shape** у нашей переменной *test_data*. Поле вызывается также как метод, но в конце скобки не ставятся (!), так как для поля не предусмотрена передача аргументов.

# %%
test_data.shape
# Out:
# (6484, 16)

# %% [markdown]
# *Что означает первое и второе число?*
# Таблица содержит 6484 строк (объектов) и 16 столбцов (признаков), включая выходной (целевой) признак. Также как в учебных данных до обучения.
#
# Таблицу проверили, теперь можно приступать к обработке данных
# Действуем аналогично тому, как делали с данными для обучения

# %% [markdown]
# Проверим, есть ли в данных пропуски. Для того чтобы это сделать, нужно обратиться вызвать у переменной *test_data* метод **info()**.

# %%
# 6. TO DO
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6484 entries, 0 to 6483
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Целевая.Цена         6484 non-null   int64
#  1   Спальни              6484 non-null   int64
#  2   Ванные               6484 non-null   float64
#  3   Жилая площадь        6484 non-null   int64
#  4   Общая площадь        6484 non-null   int64
#  5   Количество этажей    6484 non-null   float64
#  6   Вид на воду          6484 non-null   int64
#  7   Просмотрены ранее    6484 non-null   int64
#  8   Состояние            6484 non-null   int64
#  9   Оценка риелтора      6484 non-null   int64
#  10  Площадь без подвала  6484 non-null   int64
#  11  Площадь подвала      6484 non-null   int64
#  12  Год постройки        6484 non-null   int64
#  13  Год реновации        6484 non-null   int64
#  14  Широта               6484 non-null   float64
# ...

# %% [markdown]
# Цифры в каждой строчке обозначают количество заполненных (*non-null*) значений. Так как эти цифры в каждой строчке совпадают с числом строк (6484), то в данных нет пропусков.

# %% [markdown]
# **Шаг 4.2. Отделяем целевую переменную**

# %% [markdown]
# Нам нужно выделить в отдельную переменную *test_values* столбец из нашей таблицы, который соответствует определенной выше целевой переменной. Для этого мы у таблицы *test_data* в квадратных скобках указываем имя нужного столбца. В нашем случае это имя записано в переменной *target_variable_name*.

# %%
test_values = test_data[target_variable_name]

# %%
target_variable_name
# Out:
# 'Целевая.Цена'

# %% [markdown]
# Отделим входные переменные от выходной (целевой), чтобы можно было построить модель предсказания целевой переменной по входным.
# Для это нужно у переменной *test_data* вызвать метод **drop()**. Результат мы записываем в новую переменную *test_points*. После выполнения запроса *test_points* будет содержать исходную таблицу без целевого столбца.
#
# Обратите внимание, что в данном случае мы передаем два аргумента:
#     1. target_variable_name - название столбца цены, который мы ранее записали в эту переменную и теперь хотим удалить из training_data
#     2. axis=1 - означает, что мы удаляем столбец, а в случае axis=0 - означает, что мы удаляем строку

# %%
# 7. TO DO

test_points = test_data.drop(columns=target_variable_name)

# %% [markdown]
# И проверяем результат записанный в test_points

# %%
test_points.head()
# Out:
#    Спальни  Ванные  Жилая площадь  Общая площадь  Количество этажей  \
# 0        3    1.00           1300          10139                1.0
# 1        4    2.75           3280           6845                2.0
# 2        1    1.00           1220          12426                1.0
# 3        3    2.50           2880          13500                1.0
# 4        3    2.00           1300           3731                1.0
#
#    Вид на воду  Просмотрены ранее  Состояние  Оценка риелтора  \
# 0            0                  0          3                7
# 1            0                  0          3               10
# 2            0                  4          4                6
# 3            0                  4          5                8
# 4            0                  0          3                7
#
#    Площадь без подвала  Площадь подвала  Год постройки  Год реновации  \
# 0                 1300                0           1962           2007
# ...

# %%
test_points.shape
# Out:
# (6484, 15)

# %% [markdown]
# Видно, что количество столбцов уменьшилось на один. Данные в 5 первых строках такие же, как были ранее.

# %% [markdown]
# # 5. Провалидировать модель на тестовой выборке

# %% [markdown]
# **Шаг 5.1. Сравнение моделей.**
#
# Теперь мы готовы сравнить качество двух моделей! 😎

# %% [markdown]
# *1. Какая модель лучше?*
#
# Получим прогнозы целевой переменной на тестовых данных для модели линейной регрессии м модели случайного леса.
#
# Для этого вызовем у каждой модели метод **predict()**, в качестве аргумента передадим *test_points*.

# %%
test_predictions_linear = linear_regression_model.predict(test_points)

# %%
# 8. TO DO: аналогично сделать для модели RandomForest
test_predictions_random_forest = random_forest_model.predict(test_points)

# %% [markdown]
# Качество регрессионных моделей оценим двумя способами:
# 1. Сравним визуально прогнозы с настоящими ценами (тестовые с предсказанием)
# 2. Сравним метрики качества

# %% [markdown]
# Визуализируем прогноз линейной модели и настоящие значения из тестовой выборки.
# Можно не обращать особого внимания на то, что за код написан.

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(7, 7))
plt.scatter(test_values, test_predictions_linear, s=1, c='r') # рисуем точки, соответствущие парам настоящее значение - прогноз
plt.plot([0, 6 * 10**6], [0, 6 * 10**6]) # рисуем прямую, на которой предсказания и настоящие значения совпадают
plt.xlabel('Настоящая цена', fontsize=20)
plt.ylabel('Предсказанная цена', fontsize=20);

# %% [markdown]
# Визуализируем прогноз модели случайного леса и настоящие значения из тестовой выборки

# %%
plt.figure(figsize=(7, 7))
plt.scatter(test_values, test_predictions_random_forest, s=1, c='r')
plt.plot([0, 6 * 10**6], [0, 6 * 10**6])
plt.xlabel('Настоящая цена', fontsize=20)
plt.ylabel('Предсказанная цена', fontsize=20);

# %% [markdown]
# Кажется, что лучше сработала модель случайного леса, так как точки на втором изображении расположены вдоль диагонали. На первом изображении видно, что для высоких настоящих цен модель линейной регрессии дает существенно заниженный результат.
#
# Проверим, так ли это с помощью **метрик качества регрессионной модели**

# %% [markdown]
# Для корректного подсчета метрик качества модели в python требуется загрузить их из библиотеки **sklearn**.
#
# Мы используем две метрики качества:
#  * *mean_absolute_error* - средняя абсолютная ошибка $|y_i - \hat{y}_i|$
#  * *mean_squared_error* - средняя квадратичная ошибка $(y_i - \hat{y}_i)^2$
#  * *rmse* - root mean squared error

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# Подсчитаем ошибки для линейной модели.
#
# Для этого вызовем методы **mean_absolute_error()** и **mean_squared_error()**. На вход им передается столбец настоящих значений *test_values* и столбец значений, предсказанных моделью линейной регрессии *test_predictions_linear*.

# %%
# 9. TO DO
mean_absolute_error_linear_model = mean_absolute_error(test_values, test_predictions_linear)
mean_squared_error_linear_model = mean_squared_error(test_values, test_predictions_linear)

# %% [markdown]
# Подсчитаем ошибки для модели случайного леса.
#
# Для этого вызовем методы **mean_absolute_error()** и **mean_squared_error()**. На вход им передается столбец настоящих значений *test_values* и столбец значений, предсказанных моделью линейной регрессии *test_predictions_random_forest*.

# %%
# 10. TO DO
mean_absolute_error_random_forest_model = mean_absolute_error(test_values, test_predictions_random_forest)
mean_squared_error_random_forest_model = mean_squared_error(test_values, test_predictions_random_forest)

# %% [markdown]
# Теперь напечатаем полученные ошибки. Обычно смотрят на корень из среднеквадратичной ошибки, RMSE. Чтобы извлечь корень нам понадобится библиотека **Numpy**. С помощью неё можно быстро производить вычисления сразу над массивами чисел.

# %%
import numpy as np

print("MAE: {0:7.2f}, RMSE: {1:7.2f} для модели линейной регрессии".format(
        mean_absolute_error_linear_model,
        np.sqrt(mean_squared_error_linear_model)))

print("MAE: {0:7.2f}, RMSE: {1:7.2f} для модели случайного леса".format(
       mean_absolute_error_random_forest_model,
       mean_squared_error_random_forest_model**(1/2)))
# Out:
# MAE: 126852.51, RMSE: 201883.24 для модели линейной регрессии
# MAE: 70730.87, RMSE: 138782.83 для модели случайного леса

# %% [markdown]
# Модель случайного леса работает лучше и визуально, и потому, что абсолютная и средне квадратичная ошибка меньше чем у линейной регресии.

# %% [markdown]
# # Обзор результатов
#
# В этом ноутбуке мы научились
# 0. Загружать библиотеки, необходимые для работы.
# 1. Загрузить данные для обучения, представленные в формате excel таблицы.
# 2. Проводить предварительную обработку данных перед построением и использованием модели машинного обучения: смотреть на части таблицы, понимать, какой размер у выборки данных, выделять отдельные столбцы таблицы в новые таблицы.
# 3. Обучать модель линейной регрессии и решающего леса на обучающей выборке.
# 4. Валидировать модель на тестовой выборке с помощью кросс-плота для модели и реальных значений, стандартных ошибок модели.

# %% [markdown]
# ## 6. Бонус: Выявление важных признаков

# %% [markdown]
# Признаки, используемые для обучения модели, оказывают большое влияние на качество результатов. Неинформативные или слабо информативные признаки могут снизить качество модели, использование избыточных признаков в модели замедляет скорость ее работы.
#
# Для того, чтобы отобрать признаки нам следует ответить на следующие вопросы:
#     1. Все ли признаки в наших данных заполненны разумными значениями?
#     2. Какие признаки будут больше всего влиять на значение целевой переменной?
#     3*. Какие дополнительные признаки имело бы смысл добавить в список входных?

# %% [markdown]
# **6.1. Разглядывание значений признаков**
#
# Для того чтобы ответить на первый вопрос, нам необходимо получить некоторую нашу экспертную оценку данных. В наших данных нет пропусков, однако иногда пропуски предварительно заполняют другими значениями (0, 999 и другие) и их можно увидеть, только внимательно посмотрев на данные.
#
# Для того, чтобы это сделать, нужно вызвать у переменной *training_points* метод **head(10)**, который выводит первые 10 строк таблицы.

# %%
training_points.head(100)
# Out:
#     Спальни  Ванные  Жилая площадь  Общая площадь  Количество этажей  \
# 0         5    3.50           3490          21780                2.0
# 1         4    1.75           2360           7620                1.0
# 2         6    2.75           2040           8560                1.0
# 3         3    1.75           1940           8376                1.0
# 4         3    2.75           3450           5350                1.5
# ..      ...     ...            ...            ...                ...
# 95        2    1.00            700           4350                1.0
# 96        3    2.25           1620          12309                2.0
# 97        4    3.25           3250           5478                2.0
# 98        4    2.50           2430          11870                1.0
# 99        3    1.00           1590           8160                1.0
#
#     Вид на воду  Просмотрены ранее  Состояние  Оценка риелтора  \
# 0             0                  0          3                8
# ...

# %% [markdown]
# Рассмотрим столбец "Год реновации". Он содержит много нулей и мало реальных данных о годах, что как раз свидетельствует о том, что в этих данных изначально были пропуски, а к нам они попали уже заполненные нулями.
#
# Мы можем посмотреть количество уникальных значений и сколько раз эти значения встречаются в этом столбце. Для этого вызываем метод **value_counts()** у нашего столбца *training_points['Год реновации']*

# %%
training_points['Год реновации'].value_counts()
# Out:
# Год реновации
# 0       14490
# 2014       63
# 2013       31
# 2000       28
# 2003       24
#         ...
# 1950        1
# 1954        1
# 1946        1
# 1959        1
# 1955        1
# Name: count, Length: 67, dtype: int64

# %% [markdown]
# Как видно, нулей существенно больше (14490), чем любых других значений (639), поэтому можем сделать вывод, что этот признак не информативен и может негативно повлиять на качество модели.

# %% [markdown]
# **6.2. Какие признаки самые важные**
#
# Ручной перебор признаков невозможен, если их тысячи, кроме того, часто даже эксперты не могут сказать, использование каких признаков в модели даст прирост качества.
# Кроме ручного перебора всех признаков и их визуального анализа, можно использовать оценку значимости признаков с помощью обученных моделей.

# %%
# на всякий случай еще раз обучим модель, так как оценить значимость признаков можно только у уже обученной модели
# 11. TO DO
random_forest_model.fit(training_points, training_values)
# Out:
# RandomForestRegressor()

# %% [markdown]
# Получить оценку важности признаков можно вызвав поле **feature\_importances\_** у модели *random\_forest\_model*.

# %%
random_forest_model.feature_importances_
# Out:
# array([0.00383062, 0.00810153, 0.29735398, 0.02535749, 0.00258391,
#        0.0298265 , 0.01451758, 0.00425629, 0.30234056, 0.02658709,
#        0.00727853, 0.03268937, 0.00241166, 0.16939326, 0.07347161])

# %%
lst = [0.00416024, 0.00986639, 0.31225587, 0.02604045, 0.00252637,
       0.02850577, 0.01521924, 0.00401608, 0.28628914, 0.02451782,
       0.00674391, 0.02982297, 0.00243082, 0.17415179, 0.07345311]

sum(lst)
# Out:
# 0.99999997

# %% [markdown]
# Набор цифр, которые мы получили выше, соответствует признакам, на которых мы обучали модель. Посмотреть эти признаки можно, вызвав у *training_points* метод **keys()**

# %%
training_points.keys()
# Out:
# Index(['Спальни', 'Ванные', 'Жилая площадь', 'Общая площадь',
#        'Количество этажей', 'Вид на воду', 'Просмотрены ранее', 'Состояние',
#        'Оценка риелтора', 'Площадь без подвала', 'Площадь подвала',
#        'Год постройки', 'Год реновации', 'Широта', 'Долгота'],
#       dtype='object')

# %% [markdown]
# Представим полученные результаты в более удобном табличном виде. Создадим пустую таблицу *feature_importance* с двумя колонками "Название признака", "Важность признака". Для этого воспользуемся функцией **DataFrame()** из библиотеки pandas и передадим ей в качестве аргумента
# *columns = ["Название признака", "Важность признака"]*

# %%
feature_importance = pd.DataFrame(columns = ['Название признака', 'Важность признака'])

# %% [markdown]
# Заполним соответствующие колонки значениями, которые мы получили выше.

# %%
feature_importance['Название признака'] = training_points.keys()
feature_importance['Важность признака'] = random_forest_model.feature_importances_

# %%
# выведем полученную таблицу
feature_importance
# Out:
#       Название признака  Важность признака
# 0               Спальни           0.003831
# 1                Ванные           0.008102
# 2         Жилая площадь           0.297354
# 3         Общая площадь           0.025357
# 4     Количество этажей           0.002584
# 5           Вид на воду           0.029827
# 6     Просмотрены ранее           0.014518
# 7             Состояние           0.004256
# 8       Оценка риелтора           0.302341
# 9   Площадь без подвала           0.026587
# 10      Площадь подвала           0.007279
# 11        Год постройки           0.032689
# 12        Год реновации           0.002412
# 13               Широта           0.169393
# 14              Долгота           0.073472

# %% [markdown]
# Мы можем отсортировать значения по важности, вызвав у *feature_importance* метод **sort_values()**.
#
# Обратите внимание, что в данном случае мы передаем два аргумента:
#
# 1. by='Важность признака' - название столбца, по которому мы сортируем
# 2. ascending=False - означает, что мы сортируем по убиыванию, а в случае ascending=True сортировка будет по возростанию

# %%
feature_importance.sort_values(by='Важность признака', ascending=False)
# Out:
#       Название признака  Важность признака
# 8       Оценка риелтора           0.302341
# 2         Жилая площадь           0.297354
# 13               Широта           0.169393
# 14              Долгота           0.073472
# 11        Год постройки           0.032689
# 5           Вид на воду           0.029827
# 9   Площадь без подвала           0.026587
# 3         Общая площадь           0.025357
# 6     Просмотрены ранее           0.014518
# 1                Ванные           0.008102
# 10      Площадь подвала           0.007279
# 7             Состояние           0.004256
# 0               Спальни           0.003831
# 4     Количество этажей           0.002584
# 12        Год реновации           0.002412

# %% [markdown]
# ## TODO: Впишите в эту ячейку 5 наиболее и наименее значимых признаков
# Как видно, наиболее значимые признаки - это:
# - Оценка риелтора
# - Жилая площадь
# - Широта
# - Долгота
# - Год постройки
#
# Наименее важны такие признаки, как
# - Год реновации
# - Количество этажей
# - Спальни
# - Состояние
# - Площадь подвала
# - Ванные

# %% [markdown]
# Посмотрим на наиболее значимые признаки. Размер жилой площади квартиры (признак Жилая площадь) очевидным образом влияет на цену: чем больше площадь, тем квартира дороже. Важность оценки состояния квартиры риелтором (признак Оценка риелтора), также понятна. Интересно появление признака Широта в списке наиболее важных. Давайте посмотрим на карту округа Кинг.

# %% [markdown]
# <a href="https://drive.google.com/uc?id=1-76SNpWIKLYMcUibXUnCy1PFq6srIpnp
# " target="_blank"><img src="https://drive.google.com/uc?id=1-76SNpWIKLYMcUibXUnCy1PFq6srIpnp"
# alt="IMAGE ALT TEXT HERE" width="360" border="0" /></a>

# %% [markdown]
# На карте видно, что центр Сиэтла находится в верхней половине карты. Соответственно, чем ближе к нему, тем дороже будет квартира.

# %% [markdown]
# # Самостоятельная работа
#
# 1. Исключите из выборки незначащие параметры (фичи), стоящие в рейтинге фич на последних местах и посмотрите, оцените насколько ухудшилось/улучшилось качество моделей (rmse, mse, mae). Напишите об этом отчет с цифрами.
# 2. Исследуйте параметры модели Random Forest и постарайтесь получить ещё более низкое (чем в текущей реализации) значение ошибки для этой модели.
# 3. Исследуйте другие модели для реализации задачи предсказания (https://habr.com/ru/company/mailru/blog/513842/). Постарайтесь построить более точную модель.
#
# Создайте отчёт с результатами выполнения этих шагов.

# %% [markdown]
# ## 1. Оценка качества модели после исключения незначащих параметров
#
#
# > Исключите из выборки незначащие параметры (фичи), стоящие в рейтинге фич на последних местах и посмотрите, оцените насколько ухудшилось/улучшилось качество моделей (rmse, mse, mae). Напишите об этом отчет с цифрами.

# %% [markdown]
# Как мы уже выяснили самыми наименее значимыми признаками оказались: "Год реновации, Количество этажей, Спальни, Состояние, Площадь подвала, Ванные". Попробуем отбросить первые три.

# %%
twelve_training_points = training_points.drop(columns = ['Год реновации', 'Количество этажей', 'Спальни'])
twelve_test_points = test_points.drop(columns = ['Год реновации', 'Количество этажей', 'Спальни'])
print(twelve_training_points.shape)
print(twelve_test_points.shape)
# Out:
# (15129, 12)
# (6484, 12)

# %%
linear_regression_model.fit(twelve_training_points, training_values)
random_forest_model.fit(twelve_training_points, training_values)
# Out:
# RandomForestRegressor()

# %%
test_predictions_linear = linear_regression_model.predict(twelve_test_points)
test_predictions_random_forest = random_forest_model.predict(twelve_test_points)

# %%
mean_absolute_error_linear_model = mean_absolute_error(test_values, test_predictions_linear)
mean_squared_error_linear_model = mean_squared_error(test_values, test_predictions_linear)

mean_absolute_error_random_forest_model = mean_absolute_error(test_values, test_predictions_random_forest)
mean_squared_error_random_forest_model = mean_squared_error(test_values, test_predictions_random_forest)

import numpy as np

print("MAE: {0:7.2f}, RMSE: {1:7.2f} для модели линейной регрессии без 3 признаков".format(
        mean_absolute_error_linear_model,
        np.sqrt(mean_squared_error_linear_model)))

print("MAE: {0:7.2f}, RMSE: {1:7.2f} для модели случайного леса без 3 признаков".format(
       mean_absolute_error_random_forest_model,
       mean_squared_error_random_forest_model**(1/2)))
# Out:
# MAE: 127837.89, RMSE: 203210.77 для модели линейной регрессии без 3 признаков
# MAE: 70243.85, RMSE: 134389.57 для модели случайного леса без 3 признаков

# %% [markdown]
# Отбросим 6 признаков

# %%
nine_training_points = training_points.drop(columns=['Год реновации', 'Количество этажей', 'Спальни', 'Состояние', 'Площадь подвала', 'Ванные'])
nine_test_points = test_points.drop(columns=['Год реновации', 'Количество этажей', 'Спальни', 'Состояние', 'Площадь подвала', 'Ванные'], axis=1)
print(nine_training_points.shape)
print(nine_test_points.shape)
# Out:
# (15129, 9)
# (6484, 9)

# %%
linear_regression_model.fit(nine_training_points, training_values)
random_forest_model.fit(nine_training_points, training_values)
# Out:
# RandomForestRegressor()

# %%
test_predictions_linear = linear_regression_model.predict(nine_test_points)
test_predictions_random_forest = random_forest_model.predict(nine_test_points)

# %%
mean_absolute_error_linear_model = mean_absolute_error(test_values, test_predictions_linear)
mean_squared_error_linear_model = mean_squared_error(test_values, test_predictions_linear)

mean_absolute_error_random_forest_model = mean_absolute_error(test_values, test_predictions_random_forest)
mean_squared_error_random_forest_model = mean_squared_error(test_values, test_predictions_random_forest)

import numpy as np

print("MAE: {0:7.2f}, RMSE: {1:7.2f} для модели линейной регрессии без 6 признаков".format(
        mean_absolute_error_linear_model,
        np.sqrt(mean_squared_error_linear_model)))

print("MAE: {0:7.2f}, RMSE: {1:7.2f} для модели случайного леса без 6 признаков".format(
       mean_absolute_error_random_forest_model,
       mean_squared_error_random_forest_model**(1/2)))
# Out:
# MAE: 128952.64, RMSE: 204152.04 для модели линейной регрессии без 6 признаков
# MAE: 70759.51, RMSE: 134749.88 для модели случайного леса без 6 признаков

# %% [markdown]
# Сделаем сравнительную таблицу
#
# | Модель | Кол-во признаков | MAE | RMSE |
# |--------|-----------------|-----|------|
# | **Linear Regression** | 15 (все) | 126 852.51 | 201 883.24 |
# | **Linear Regression** | 12  | 127 837.89 | 203 210.77 |
# | **Linear Regression** | 9  | 128 952.64 | 204 152.04 |
# | **Random Forest** | 15 (все) | 70 730.87 | 138 782.83 |
# | **Random Forest** | 12  | 70 243.85 | 134 389.57 |
# | **Random Forest** | 9  | 70 759.51 | 134 749.88 |

# %% [markdown]
# Если учитывать особенности используемых моделей и характер данных, можно сформулировать следующие выводы. Линейная регрессия демонстрирует снижение точности при исключении любых признаков. Даже признаки с минимальным вкладом содержат полезный линейный сигнал, который в совокупности повышает качество предсказаний модели.
#
# В случае с лесом решений наблюдается иная картина. При удалении трёх признаков заметны изменения в метрике RMSE, тогда как MAE остаётся практически неизменной; при исключении шести признаков ситуация становится обратной. В целом, такие колебания не являются существенными, поскольку дерево решений изначально устойчиво к шумным данным и наличию нерелевантных признаков, что делает его менее чувствительным к подобным изменениям.

# %% [markdown]
# ## 2. Исследование параметров Random Forest
#
#
# > Исследуйте параметры модели Random Forest и постарайтесь получить ещё более низкое (чем в текущей реализации) значение ошибки для этой модели.

# %% [markdown]
# Для улучшения результата (снижения MAE и RMSE) мы изменим подход к следующим параметрам:
#
#   -  n_estimators: увеличим до 400. Больше деревьев — стабильнее результат и меньше «шума» в предсказаниях.
#
#   -  max_features: установим в значение 0.8. Это заставит каждое дерево обучаться на случайном подмножестве признаков, что снизит корреляцию между ними и уменьшит общую ошибку.
#
#   -  min_samples_leaf: установим значение 2. Это предотвратит создание слишком глубоких «листьев», которые запоминают шум (переобучение), и заставит модель искать общие закономерности.
#
#   -  max_depth: вместо None поставим 20. Ограничение глубины — самый простой способ не дать модели «зазубрить» тренировочные данные.

# %% [markdown]
# Инициализация модели
# Создаем объект с оптимизированными гиперпараметрами

# %%
from sklearn.ensemble import RandomForestRegressor

# Выставляем параметры для снижения вариативности и переобучения
rand_forest = RandomForestRegressor(
    n_estimators=400,
    max_features=0.8,
    min_samples_leaf=2,
    max_depth= 20,
    n_jobs=-1,
    random_state=42
)

# %% [markdown]
# Обучение
# Запуск процесса на тренировочных данных

# %%
# Обучаем модель на всех 15 признаках
rand_forest.fit(training_points, training_values)
# Out:
# RandomForestRegressor(max_depth=20, max_features=0.8, min_samples_leaf=2,
#                       n_estimators=400, n_jobs=-1, random_state=42)

# %% [markdown]
# Предсказание и расчет метрик
# Оценка качества на тестовой выборке

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

test_predict_rand_forest = rand_forest.predict(test_points)

mae = mean_absolute_error(test_values, test_predict_rand_forest)
rmse = mean_squared_error(test_values, test_predict_rand_forest)**(1/2)

print(f"MAE: {mae:7.2f}, RMSE: {rmse:7.2f} для оптимизированной модели")
# Out:
# MAE: 69971.37, RMSE: 133591.34 для оптимизированной модели

# %% [markdown]
# Итого: После серии экспериментов с конфигурациями параметров был достигнут лучший результат, представленный выше. MAE снизился на 1.07% (с 70 730.87 до 69 971.37), а RMSE снизился на 3.74% (с 138 782.83 до 133 591.34).
#
# Такое значительное улучшение RMSE при небольшом изменении MAE говорит о том, что модель стала делать гораздо меньше грубых ошибок (выбросов). Можно сделать вывод, что за счет оптимизации max_features и введения ограничений на глубину был достигнут предел точности для текущего набора данных без применения дополнительного проектирования признаков.

# %% [markdown]
# ## 3. Исследование других моделей
#
#
# > Исследуйте другие модели для реализации задачи предсказания (https://habr.com/ru/company/mailru/blog/513842/). Постарайтесь построить более точную модель.

# %% [markdown]
# Были выбраны следующие вариации классической линеной регрессии:
#  - LassoCV
#  - RidgeCV
#  - ElasticNetCV
#  - CatBoost
#  - XGBoost

# %% [markdown]
# Создадим функцию вывода метрик:

# %%
def metrics_mae_rmse(prediction_values, model_name="модели"):
    mean_absolute_error_model = mean_absolute_error(test_values, prediction_values)
    mean_squared_error_model = mean_squared_error(test_values, prediction_values)

    print("MAE: {0:7.2f}, RMSE: {1:7.2f} для {2}".format(
        mean_absolute_error_model,
        np.sqrt(mean_squared_error_model),
        model_name
    ))

# %% [markdown]
# Подготовка данных для линейных моделей

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# Обучаем scaler только на тренировочных данных, чтобы избежать утечки данных (data leak)
training_points_scaled = scaler.fit_transform(training_points)
test_points_scaled = scaler.transform(test_points)

# %% [markdown]
# Обучение линейных моделей с кросс-валидацией

# %%
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV

# Ridge (L2 регуляризация)
ridge_model = RidgeCV(alphas=np.logspace(-3, 3, 10))
ridge_model.fit(training_points_scaled, training_values)
metrics_mae_rmse(ridge_model.predict(test_points_scaled), "RidgeCV")

# Lasso (L1 регуляризация - отбор признаков)
lasso_model = LassoCV(alphas=np.logspace(-3, 3, 10), random_state=42, n_jobs=-1)
lasso_model.fit(training_points_scaled, training_values)
metrics_mae_rmse(lasso_model.predict(test_points_scaled), "LassoCV")

# ElasticNet (L1 + L2)
elastic_model = ElasticNetCV(l1_ratio=[.1, .5, .7, .9, .95, .99, 1], random_state=42, n_jobs=-1)
elastic_model.fit(training_points_scaled, training_values)
metrics_mae_rmse(elastic_model.predict(test_points_scaled), "ElasticNetCV")
# Out:
# MAE: 126741.25, RMSE: 201882.73 для RidgeCV
# MAE: 126722.02, RMSE: 201861.69 для LassoCV
# MAE: 126661.58, RMSE: 201852.93 для ElasticNetCV

# %% [markdown]
# Обучение моделей градиентного бустинга

# %%
# XGBoost
from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    n_jobs=-1,
    random_state=42
)
xgb_model.fit(training_points, training_values)
metrics_mae_rmse(xgb_model.predict(test_points), "XGBoost")

# CatBoost
# !pip install catboost -q
from catboost import CatBoostRegressor

cat_model = CatBoostRegressor(
    iterations=500,
    learning_rate=0.05,
    depth=6,
    verbose=0, # Отключаем полотно логов при обучении
    random_state=42
)
cat_model.fit(training_points, training_values)
metrics_mae_rmse(cat_model.predict(test_points), "CatBoost")
# Out:
# MAE: 66199.99, RMSE: 124192.38 для XGBoost
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 9.7 MB/s eta 0:00:00
# MAE: 67147.82, RMSE: 113515.24 для CatBoost

# %% [markdown]
# ## Итоги исследования
#
# Линейные модели (Lasso, Ridge, ElasticNet) показали слабую эффективность с MAE в районе 126 000, что подтверждает нелинейную структуру данных. Ансамблевые методы справились значительно лучше.
# Сравнение лидеров:
#
#   -  XGBoost обеспечил минимальную среднюю ошибку (MAE: 66 200), лучше всего предсказывая типичные объекты.
#
#   -  CatBoost стал победителем по общей стабильности, показав наименьший RMSE (113 515). Это означает, что он на 9% эффективнее XGBoost справляется с крупными ценовыми выбросами.
#
#   -  Random Forest после тюнинга (max_features=0.8, min_samples_leaf=2) смог преодолеть порог в 70 000 MAE, но уступил бустингу в способности итеративно исправлять ошибки.
#
# Заключение: Для итоговой реализации рекомендуется CatBoost, так как низкий RMSE критически важен для минимизации «дорогих» промахов модели. Дальнейшее снижение ошибки (ниже 65k) возможно только через Feature Engineering (создание новых признаков) или логарифмирование целевой переменной, так как потенциал подбора гиперпараметров практически исчерпан.
